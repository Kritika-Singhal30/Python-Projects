# %%
import numpy as np
import pandas as pd
import  matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
cs=pd.read_csv(r"C:\Users\POOJA SINGHAL\Desktop\Fingertips\Python\Projects\Project 5\Python_Project_5_Dec.csv")
cs
# Out:
#       Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0              0   70172    Male     Loyal Customer   13  Personal Travel
# 1              1    5047    Male  disloyal Customer   25  Business travel
# 2              2  110028  Female     Loyal Customer   26  Business travel
# 3              3   24026  Female     Loyal Customer   25  Business travel
# 4              4  119299    Male     Loyal Customer   61  Business travel
# ...          ...     ...     ...                ...  ...              ...
# 9995        9995  124365    Male     Loyal Customer   50  Business travel
# 9996        9996   22044    Male     Loyal Customer   38  Business travel
# 9997        9997   14057  Female     Loyal Customer   39  Business travel
# 9998        9998  113848    Male     Loyal Customer   52  Business travel
# 9999        9999    1865  Female     Loyal Customer   41  Business travel
#
#          Class  Flight Distance  Inflight wifi service  \
# ...

# %%
cs.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
cs.describe()
# Out:
#         Unnamed: 0             id           Age  Flight Distance  \
# count  10000.00000   10000.000000  10000.000000     10000.000000
# mean    4999.50000   64950.978500     39.303700      1198.823800
# std     2886.89568   37420.905082     15.116478      1001.774138
# min        0.00000       8.000000      7.000000        31.000000
# 25%     2499.75000   32330.500000     27.000000       413.000000
# 50%     4999.50000   64941.000000     40.000000       852.500000
# 75%     7499.25000   97579.750000     51.000000      1747.000000
# max     9999.00000  129863.000000     85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count           10000.000000                       10000.000000
# mean                2.731500                           3.038900
# std                 1.328226                           1.528077
# min                 0.000000                           0.000000
# ...

# %%
cs=cs.drop("Unnamed: 0", axis=1)

# %%
cs
# Out:
#           id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0      70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1       5047    Male  disloyal Customer   25  Business travel  Business
# 2     110028  Female     Loyal Customer   26  Business travel  Business
# 3      24026  Female     Loyal Customer   25  Business travel  Business
# 4     119299    Male     Loyal Customer   61  Business travel  Business
# ...      ...     ...                ...  ...              ...       ...
# 9995  124365    Male     Loyal Customer   50  Business travel  Business
# 9996   22044    Male     Loyal Customer   38  Business travel  Business
# 9997   14057  Female     Loyal Customer   39  Business travel  Business
# 9998  113848    Male     Loyal Customer   52  Business travel  Business
# 9999    1865  Female     Loyal Customer   41  Business travel  Business
#
#       Flight Distance  Inflight wifi service  \
# 0                 460                      3
# ...

# %%
cs.columns=[each.replace(" ","_") for each in cs.columns]

# %%
cs.columns  # space replaced with underscore
# Out:
# Index(['id', 'Gender', 'Customer_Type', 'Age', 'Type_of_Travel', 'Class',
#        'Flight_Distance', 'Inflight_wifi_service',
#        'Departure/Arrival_time_convenient', 'Ease_of_Online_booking',
#        'Gate_location', 'Food_and_drink', 'Online_boarding', 'Seat_comfort',
#        'Inflight_entertainment', 'On-board_service', 'Leg_room_service',
#        'Baggage_handling', 'Checkin_service', 'Inflight_service',
#        'Cleanliness', 'Departure_Delay_in_Minutes', 'Arrival_Delay_in_Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
cs['satisfaction'].value_counts()
# Out:
# neutral or dissatisfied    5689
# satisfied                  4311
# Name: satisfaction, dtype: int64

# %%
plt.title("Satisfied Customers v/s Unsatisfied Customers")
sns.countplot(cs['satisfaction'])
plt.show()
# Out:
# C:\Users\POOJA SINGHAL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
cs["satisfaction"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
cs["Gender"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
cs["satisfaction"]=[1 if each=="satisfied" else 0 for each in cs.satisfaction]

# %%
plt1=cs[["Gender","satisfaction"]].groupby(["Gender"],as_index=False).mean().sort_values(by="satisfaction",ascending=False)
plt1
# Out:
#    Gender  satisfaction
# 1    Male      0.438062
# 0  Female      0.424432

# %%
cs[["Age","satisfaction"]].groupby(["Age"],as_index=False).mean().sort_values(by="satisfaction",ascending=False)
# Out:
#     Age  satisfaction
# 71   79      0.666667
# 39   46      0.643192
# 34   41      0.632743
# 38   45      0.608466
# 66   73      0.600000
# ..  ...           ...
# 7    14      0.076923
# 0     7      0.071429
# 59   66      0.050000
# 69   76      0.000000
# 73   85      0.000000
#
# [74 rows x 2 columns]

# %%
cs[["Food_and_drink","satisfaction"]].groupby(["Food_and_drink"],as_index=False).mean().sort_values(by="satisfaction",ascending=False)
# Out:
#    Food_and_drink  satisfaction
# 0               0      0.625000
# 5               5      0.566176
# 4               4      0.515050
# 3               3      0.404990
# 2               2      0.362305
# 1               1      0.198142

# %%
cs.isnull().sum()
# Out:
# id                                    0
# Gender                                0
# Customer_Type                         0
# Age                                   0
# Type_of_Travel                        0
# Class                                 0
# Flight_Distance                       0
# Inflight_wifi_service                 0
# Departure/Arrival_time_convenient     0
# Ease_of_Online_booking                0
# Gate_location                         0
# Food_and_drink                        0
# Online_boarding                       0
# Seat_comfort                          0
# Inflight_entertainment                0
# On-board_service                      0
# Leg_room_service                      0
# Baggage_handling                      0
# Checkin_service                       0
# Inflight_service                      0
# Cleanliness                           0
# Departure_Delay_in_Minutes            0
# Arrival_Delay_in_Minutes             26
# ...

# %%
cs= cs.dropna()

# %%
cs.isnull().sum()
# Out:
# id                                   0
# Gender                               0
# Customer_Type                        0
# Age                                  0
# Type_of_Travel                       0
# Class                                0
# Flight_Distance                      0
# Inflight_wifi_service                0
# Departure/Arrival_time_convenient    0
# Ease_of_Online_booking               0
# Gate_location                        0
# Food_and_drink                       0
# Online_boarding                      0
# Seat_comfort                         0
# Inflight_entertainment               0
# On-board_service                     0
# Leg_room_service                     0
# Baggage_handling                     0
# Checkin_service                      0
# Inflight_service                     0
# Cleanliness                          0
# Departure_Delay_in_Minutes           0
# Arrival_Delay_in_Minutes             0
# satisfaction                         0
# dtype: int64

# %%
cs['Flight_Distance'].unique()
# Out:
# array([ 460,  235, 1142, ..., 3033, 1319, 1443], dtype=int64)

# %% [markdown]
# # Part 2

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

# %%
cs[['Gender','Customer_Type','Type_of_Travel','Class']]=cs[['Gender','Customer_Type','Type_of_Travel','Class']].apply(labelencoder.fit_transform)
# Out:
# C:\Users\POOJA SINGHAL\anaconda3\lib\site-packages\pandas\core\frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
cs.head(10)
# Out:
#        id  Gender  Customer_Type  Age  Type_of_Travel  Class  Flight_Distance  \
# 0   70172       1              0   13               1      2              460
# 1    5047       1              1   25               0      0              235
# 2  110028       0              0   26               0      0             1142
# 3   24026       0              0   25               0      0              562
# 4  119299       1              0   61               0      0              214
# 5  111157       0              0   26               1      1             1180
# 6   82113       1              0   47               1      1             1276
# 7   96462       0              0   52               0      0             2035
# 8   79485       0              0   41               0      0              853
# 9   65725       1              1   20               0      1             1061
#
#    Inflight_wifi_service  Departure/Arrival_time_convenient  \
# ...

# %%
cs= cs.drop('id',axis=1)
cs
# Out:
#       Gender  Customer_Type  Age  Type_of_Travel  Class  Flight_Distance  \
# 0          1              0   13               1      2              460
# 1          1              1   25               0      0              235
# 2          0              0   26               0      0             1142
# 3          0              0   25               0      0              562
# 4          1              0   61               0      0              214
# ...      ...            ...  ...             ...    ...              ...
# 9995       1              0   50               0      0             3599
# 9996       1              0   38               0      0             3873
# 9997       0              0   39               0      0              319
# 9998       1              0   52               0      0             1363
# 9999       0              0   41               0      0             3938
#
#       Inflight_wifi_service  Departure/Arrival_time_convenient  \
# ...

# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
X=cs.drop('satisfaction',axis=1)  #features data 
Y=cs['satisfaction'] #target data

# %%
X.head(10)
# Out:
#    Gender  Customer_Type  Age  Type_of_Travel  Class  Flight_Distance  \
# 0       1              0   13               1      2              460
# 1       1              1   25               0      0              235
# 2       0              0   26               0      0             1142
# 3       0              0   25               0      0              562
# 4       1              0   61               0      0              214
# 5       0              0   26               1      1             1180
# 6       1              0   47               1      1             1276
# 7       0              0   52               0      0             2035
# 8       0              0   41               0      0              853
# 9       1              1   20               0      1             1061
#
#    Inflight_wifi_service  Departure/Arrival_time_convenient  \
# 0                      3                                  4
# 1                      3                                  2
# ...

# %%
#scalining on features data 
from sklearn.preprocessing import StandardScaler
std_scal = StandardScaler()
X_scal = std_scal.fit_transform(X)
X
# Out:
#       Gender  Customer_Type  Age  Type_of_Travel  Class  Flight_Distance  \
# 0          1              0   13               1      2              460
# 1          1              1   25               0      0              235
# 2          0              0   26               0      0             1142
# 3          0              0   25               0      0              562
# 4          1              0   61               0      0              214
# ...      ...            ...  ...             ...    ...              ...
# 9995       1              0   50               0      0             3599
# 9996       1              0   38               0      0             3873
# 9997       0              0   39               0      0              319
# 9998       1              0   52               0      0             1363
# 9999       0              0   41               0      0             3938
#
#       Inflight_wifi_service  Departure/Arrival_time_convenient  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,train_size=0.8,random_state=10)

# %%
print(X_train.shape)
# Out:
# (7979, 22)

# %%
X_test.shape
# Out:
# (1995, 22)

# %%
X_train
# Out:
#       Gender  Customer_Type  Age  Type_of_Travel  Class  Flight_Distance  \
# 9852       0              0   33               0      0             3904
# 1902       1              0   62               1      1              862
# 1318       1              0   11               0      0              622
# 2032       1              0   28               1      1              957
# 5504       0              0   60               0      0             3913
# ...      ...            ...  ...             ...    ...              ...
# 9394       1              0   50               1      1              429
# 7309       0              0   70               1      1              550
# 1346       1              1   39               0      1              237
# 7311       1              1   38               0      1              578
# 1291       0              1   64               0      0              312
#
#       Inflight_wifi_service  Departure/Arrival_time_convenient  \
# ...

# %%
from sklearn.tree import DecisionTreeClassifier #Decision Tree
from sklearn.model_selection import train_test_split#Train Test Split
from sklearn import metrics
from sklearn import tree

# %%
decisiontree_model = tree.DecisionTreeClassifier()

# %%
decisiontree_model.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
decisiontree_model.score(X_train,Y_train)
# Out:
# 1.0

# %%
decisiontree_model.score(X_test,Y_test)
# Out:
# 0.9328320802005012

# %%
Y_prediction  = decisiontree_model.predict(X_test)
Y_prediction
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int64)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,precision_score,recall_score,f1_score

# %%
print("pricison_score: ",precision_score(Y_test, Y_prediction))
print("recall_score: ",recall_score(Y_test, Y_prediction))
print("accuracy_score:" ,accuracy_score(Y_test,Y_prediction))
# Out:
# pricison_score:  0.9108796296296297
# recall_score:  0.9324644549763034
# accuracy_score: 0.9328320802005012

# %%
#Classification report 
print(classification_report(Y_test,Y_prediction,digits=5))
# Out:
#               precision    recall  f1-score   support
#
#            0    0.94960   0.93310   0.94128      1151
#            1    0.91088   0.93246   0.92155       844
#
#     accuracy                        0.93283      1995
#    macro avg    0.93024   0.93278   0.93141      1995
# weighted avg    0.93322   0.93283   0.93293      1995

# %%
print(confusion_matrix(Y_test,Y_prediction))
print(f1_score(Y_test,Y_prediction))
# Out:
# [[1074   77]
#  [  57  787]]
# 0.9215456674473068
